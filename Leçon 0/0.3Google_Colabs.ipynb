# %% [markdown]
# # Google Colabs

# %% [markdown]
# Si vous ne possédez pas un ordinateur, vous avez aussi l'option de programmer dans le navigateur de votre choix.

# %% [markdown]
# # Créer un Cahier

# %% [markdown]
# Clickez [ici](https://colab.research.google.com/?utm_source=scs-index) pour ouvrir Google colab.

# %% [markdown]
# <img src="L_01_img/google_coloab_start_page.png"/>

# %% [markdown]
# Pour l'utiliser, il faut avoir un compte avec Google. Après avoir enregistré, vous devriez voir cette page:

# %% [markdown]
# <img src="L_01_img/google_colab_start_home_screen.png"/>

# %% [markdown]
# Cliquez sur `nouveau notebook` pour commencer

# %% [markdown]
# Si vous réussissez, vous voyez cet écran. Pour programmer, il faut simplement saisir les commands dans le champ text et poussez le bouton lecture

# %% [markdown]
# <img src="L_01_img/hello_world.png"/>

# %% [markdown]
# Et voilà !
